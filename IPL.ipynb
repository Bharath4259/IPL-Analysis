# %%
import pandas as pd
mdf = pd.read_csv("data/ipl_matches.csv")
# print(mdf.head(5))

# %%
team_colors = {'Chennai Super Kings':'#fdb913', 
               'Deccan Chargers':'#223256', 
               'Delhi Daredevils':'#0064ac', 
               'Gujarat Lions':'#aa2626', 
               'Kings XI Punjab':'#c22125', 
               'Kochi Tuskers Kerala':'#ff502f', 
               'Kolkata Knight Riders':'#51326a', 
               'Mumbai Indians':'#0061a2', 
               'Pune Warriors':'#c14ec3', 
               'Rajasthan Royals':'#175daa', 
               'Rising Pune Supergiants':'#c14ec3', 
               'Royal Challengers Bangalore':'#4e4f4f',
               'Sunrisers Hyderabad':'#f37200'}

# %% [markdown]
# To Get values of perticular season (column)

# %%
# To Get values of perticular season (column)
season_2008 = mdf.loc[mdf['season'] == 2008]
season_2008
# Out:
#     id  season        city        date                        team1  \
# 0    1    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 1    2    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 2    3    2008       Delhi  2008-04-19             Rajasthan Royals
# 3    4    2008      Mumbai  2008-04-20               Mumbai Indians
# 4    5    2008     Kolkata  2008-04-20              Deccan Chargers
# 5    6    2008      Jaipur  2008-04-21              Kings XI Punjab
# 6    7    2008   Hyderabad  2008-04-22              Deccan Chargers
# 7    8    2008     Chennai  2008-04-23          Chennai Super Kings
# 8    9    2008   Hyderabad  2008-04-24              Deccan Chargers
# 9   10    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 10  11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 11  12    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 12  13    2008      Mumbai  2008-04-27               Mumbai Indians
# ...

# %% [markdown]
# #### Use .last_valid_index() to get last index

# %%
# Use .last_valid_index() to get last index of a data frame
last_index = season_2008.last_valid_index()
print(last_index)
# Out:
# 57

# %%
#Data of last index
last_row = season_2008.iloc[[last_index]]
last_row
# Out:
#     id  season    city        date                team1             team2  \
# 57  58    2008  Mumbai  2008-06-01  Chennai Super Kings  Rajasthan Royals
#
#          toss_winner toss_decision  result  dl_applied            winner  \
# 57  Rajasthan Royals         field  normal           0  Rajasthan Royals
#
#     win_by_runs  win_by_wickets player_of_match                       venue  \
# 57            0               3       YK Pathan  Dr DY Patil Sports Academy
#
#       umpire1      umpire2  umpire3
# 57  BF Bowden  RE Koertzen      NaN

# %%
# Get cell value with row number and column name
# row number = 57 
# column name = team1
last_row.loc[57].at['team1']  # use last_index instead od 57
# Out:
# 'Chennai Super Kings'

# %%
# Get teams details
teams = [last_row.loc[last_index].at['team1'], last_row.loc[last_index].at['team2']]
teams
# Out:
# ['Chennai Super Kings', 'Rajasthan Royals']

# %%
teams = [last_row[['team1']], last_row[['team2']]]
print(teams)
# Out:
# [                  team1
# 57  Chennai Super Kings,                team2
# 57  Rajasthan Royals]

# %%
winner = last_row[['winner']]
print(winner)
# Out:
#               winner
# 57  Rajasthan Royals

# %%
matches = []
# print(mdf.head(2))
prev_index = 0
for year in range(2008, 2017):
    season = mdf.loc[mdf['season'] == year]
#     print(season)
    last_index = season.last_valid_index()   #.last_valid_index() will return last index
    last_row = mdf.iloc[[last_index]]                    #Data of last index
    teams = [year, last_row.loc[last_index].at['team1'], last_row.loc[last_index].at['team2'], last_row.loc[last_index].at['winner']]
    matches.append(teams)
    
# print(matches)
# Winners data of each IPL season
final_matches_df = pd.DataFrame(matches, columns=['year', 'team1', 'team2', 'winner_team'])
final_matches_df
# Out:
#    year                team1                        team2  \
# 0  2008  Chennai Super Kings             Rajasthan Royals
# 1  2009      Deccan Chargers  Royal Challengers Bangalore
# 2  2010  Chennai Super Kings               Mumbai Indians
# 3  2011  Chennai Super Kings  Royal Challengers Bangalore
# 4  2012  Chennai Super Kings        Kolkata Knight Riders
# 5  2013       Mumbai Indians          Chennai Super Kings
# 6  2014      Kings XI Punjab        Kolkata Knight Riders
# 7  2015       Mumbai Indians          Chennai Super Kings
# 8  2016  Sunrisers Hyderabad  Royal Challengers Bangalore
#
#              winner_team
# 0       Rajasthan Royals
# 1        Deccan Chargers
# 2    Chennai Super Kings
# 3    Chennai Super Kings
# 4  Kolkata Knight Riders
# 5         Mumbai Indians
# 6  Kolkata Knight Riders
# 7         Mumbai Indians
# 8    Sunrisers Hyderabad

# %% [markdown]
# # City wise winning data

# %%
# Reading csv file again bcz we're getting a NameError showing " NameError: name 'mdf' is not defined "
# mdf = pd.read_csv("data/ipl_matches.csv")
city_mList = [mdf['winner'].tolist(), mdf['city'].tolist()]
x = map(list, zip(*city_mList))    # Getting a transpose 

city_matches = pd.DataFrame(list(x), columns=['winner', 'city'])
# city_matches

grouped_lst = city_matches[['winner', 'city']].groupby(['winner','city'], sort=True, group_keys=True)['city'].count()
grouped_lst = grouped_lst.reset_index(name ="count") #getting count of each cities they won
grouped_lst.head(50)
# Out:
#                  winner            city  count
# 0   Chennai Super Kings       Abu Dhabi      1
# 1   Chennai Super Kings       Bangalore      4
# 2   Chennai Super Kings       Centurion      2
# 3   Chennai Super Kings      Chandigarh      3
# 4   Chennai Super Kings         Chennai     33
# 5   Chennai Super Kings           Delhi      5
# 6   Chennai Super Kings      Dharamsala      1
# 7   Chennai Super Kings          Durban      1
# 8   Chennai Super Kings     East London      1
# 9   Chennai Super Kings       Hyderabad      2
# 10  Chennai Super Kings          Jaipur      2
# 11  Chennai Super Kings    Johannesburg      1
# 12  Chennai Super Kings       Kimberley      1
# 13  Chennai Super Kings         Kolkata      4
# 14  Chennai Super Kings          Mumbai      8
# 15  Chennai Super Kings  Port Elizabeth      2
# 16  Chennai Super Kings            Pune      1
# 17  Chennai Super Kings          Ranchi      3
# 18  Chennai Super Kings         Sharjah      1
# ...

# %%
# Teames with city they most won
max_win_list = grouped_lst.loc[grouped_lst.groupby(["winner"])['count'].idxmax()]
pd.DataFrame(max_win_list)  #To convert it into DataFrame
# Out:
#                           winner           city  count
# 4            Chennai Super Kings        Chennai     33
# 24               Deccan Chargers        Cuttack      3
# 42              Delhi Daredevils          Delhi     19
# 60                 Gujarat Lions         Kanpur      2
# 70               Kings XI Punjab     Chandigarh     20
# 89          Kochi Tuskers Kerala          Kochi      2
# 102        Kolkata Knight Riders        Kolkata     33
# 118               Mumbai Indians         Mumbai     40
# 127                Pune Warriors           Pune      4
# 139             Rajasthan Royals         Jaipur     24
# 149      Rising Pune Supergiants  Visakhapatnam      2
# 151  Royal Challengers Bangalore      Bangalore     29
# 172          Sunrisers Hyderabad      Hyderabad     14

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# data = grouped_lst.loc[grouped_lst['winner'] == 'Chennai Super Kings' ]  # Get team wise data

# %% [markdown]
# ## Displaying team wise winning count in each city

# %%
# Using matplotlib
'''
for i in grouped_lst.winner.unique():
    data = grouped_lst.loc[grouped_lst['winner'] == i ]
    data2 =  data[['city', 'count']]
    data2 = data.set_index('city')
    data2.plot(kind='bar',figsize=(20,7), color=team_colors[i])
    plt.xlabel('CIties')
    plt.ylabel('no of matches won')
    plt.title(i)
    plt.show()
'''
# Out:
# "\nfor i in grouped_lst.winner.unique():\n    data = grouped_lst.loc[grouped_lst['winner'] == i ]\n    data2 =  data[['city', 'count']]\n    data2 = data.set_index('city')\n    data2.plot(kind='bar',figsize=(20,7), color=team_colors[i])\n    plt.xlabel('CIties')\n    plt.ylabel('no of matches won')\n    plt.title(i)\n    plt.show()\n"

# %%
# Using Seaborn
# fig, ax = plt.subplots(7, 3, sharex='col', sharey='row')
for i in grouped_lst.winner.unique():
    data = grouped_lst.loc[grouped_lst['winner'] == i ]
    data2 =  data[['city', 'count']]
    ax = sns.barplot(x='city', y='count', data = data2, color=team_colors[i])
    plt.xticks(rotation=90)
    plt.title(i)
    plt.show()
    
# ax

# %%
# fig, axes = plt.subplots(10,2,figsize=(50,150))
# j=0
# for i in grouped_lst.winner.unique():
#     data = grouped_lst.loc[grouped_lst['winner'] == i ]
#     data2 =  data[['city', 'count']]
#     ax = sns.barplot(x='city', y='count', data = data2, color=team_colors[i], ax=axes[j//10, j%2])
#     plt.xticks(rotation=90)
#     plt.title(i)
# #     plt.show()
#     j += 1

# %%
# x = sns.FacetGrid(grouped_lst, row='city', col='count')
# x.map(plt.hist, 'winner')

# %%
# fig, axes = plt.subplots(10,2,figsize=(50,150))
# j=0
# k=0
# teamList = grouped_lst.winner.unique()
# for i in grouped_lst.winner.unique():
#     data = grouped_lst.loc[grouped_lst['winner'] == i ]
#     data2 =  data[['city', 'count']]
#     ax = sns.barplot(x='city', y='count', data = data2, color=team_colors[i], ax=axes[j, k])
#     plt.xticks(rotation=90)
#     plt.title(i)
# #     plt.show()
    
        
#     j += 1
#     k += 1
#     if(k>1):
#         k=0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-a71adf5df48e> in <module>()
#       6     data = grouped_lst.loc[grouped_lst['winner'] == i ]
#       7     data2 =  data[['city', 'count']]
# ----> 8     ax = sns.barplot(x='city', y='count', data = data2, color=team_colors[i], ax=axes[j, k])
#       9     plt.xticks(rotation=90)
#      10     plt.title(i)
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
grouped_lst.winner.unique()[0]
# Out:
# 'Chennai Super Kings'
